# %%
import os
from dotenv import load_dotenv

# .envファイルを読み込む
load_dotenv()

os.environ["openai_api_key"] = os.getenv("OPENAI_API_KEY")
os.environ["openai_api_base"] = os.getenv("OPENAI_API_BASE")
os.environ["openai_model"] = os.getenv("OPENAI_MODEL")

# %%
import sys
import os

# プロジェクトのルートパスを追加（必要に応じて階層を調整）
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from src.agent import HelpDeskAgent
from src.configs import Settings
from src.tools.search_db import search_db_qa

settings = Settings()

# %%
settings = Settings()

# %%
agent = HelpDeskAgent(
    settings=settings,
    tools=[search_db_qa],
)

# %%
# question = """
# お世話になっております。

# 現在、XYZシステムの利用を検討しており、以下の2点についてご教示いただければと存じます。

# 1. パスワードに利用可能な文字の制限について
# 当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

# 2. 最新リリースの取得方法について
# 最新のアップデート情報をどのように確認・取得できるかについてもお教えいただけますと幸いです。

# お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。

# """

# question = """
# お世話になっております。

# 現在、XYZシステムを利用しており、以下の点についてご教示いただければと存じます。

# 1. 特定のプロジェクトに対してのみ通知を制限する方法について
# 特定のプロジェクトに対してのみ通知を制限する方法についてお教えいただけますと幸いです。

# 2. パスワードに利用可能な文字の制限について
# 当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

# お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。
# """

question = """
お世話になっております。

現在Reactの利用を検討しており、以下の2点についてご教示いただければと思います。

1. Reactの初期セットアップについて

2. Reactの主な使い方について

お忙しいところ恐縮ですが、ご対応の程よろしくお願いします。
"""

# %% [markdown]
# ## ヘルプデスクエージェント全体を実行します

# %%
result = agent.run_agent(question)
# Out:
# 2025-07-22 16:16:38,068 INFO 🚀 Starting plan generation process...
# 2025-07-22 16:16:38,069 INFO Sending request to OpenAI...
# 2025-07-22 16:16:42,401 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:42,453 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:42,454 INFO Plan generation complete!
# 2025-07-22 16:16:42,476 INFO 🚀 Starting tool selection process...
# 2025-07-22 16:16:42,491 INFO 🚀 Starting tool selection process...
# 2025-07-22 16:16:42,496 INFO 🚀 Starting tool selection process...
# 2025-07-22 16:16:42,501 INFO Sending request to OpenAI...
# 2025-07-22 16:16:42,517 INFO 🚀 Starting tool selection process...
# 2025-07-22 16:16:42,538 INFO Sending request to OpenAI...
# 2025-07-22 16:16:42,544 INFO 🚀 Starting tool selection process...
# 2025-07-22 16:16:42,547 INFO Sending request to OpenAI...
# 2025-07-22 16:16:42,555 INFO Sending request to OpenAI...
# 2025-07-22 16:16:42,561 INFO Sending request to OpenAI...
# 2025-07-22 16:16:43,697 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:43,705 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:43,706 INFO Tool selection complete!
# 2025-07-22 16:16:43,708 INFO 🚀 Starting tool execution process...
# 2025-07-22 16:16:43,710 INFO Searching by query: {"query":"React イベントハンドリング 方法"}
# 2025-07-22 16:16:43,942 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:43,950 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:43,952 INFO Tool selection complete!
# 2025-07-22 16:16:43,953 INFO 🚀 Starting tool execution process...
# 2025-07-22 16:16:43,954 INFO Searching by query: {"query":"React 初期セットアップ 必要なソフトウェア ツール"}
# 2025-07-22 16:16:44,529 INFO Generating embedding vector from input query
# 2025-07-22 16:16:44,923 INFO Generating embedding vector from input query
# 2025-07-22 16:16:44,925 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:44,927 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:44,927 INFO Tool selection complete!
# 2025-07-22 16:16:44,928 INFO 🚀 Starting tool execution process...
# 2025-07-22 16:16:44,929 INFO Searching by query: {"query":"React 初期セットアップ 手順"}
# 2025-07-22 16:16:45,092 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-22 16:16:45,294 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:45,304 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:45,304 INFO Tool selection complete!
# 2025-07-22 16:16:45,305 INFO 🚀 Starting tool execution process...
# 2025-07-22 16:16:45,307 INFO Searching by query: {"query":"React 状態管理 方法"}
# 2025-07-22 16:16:45,363 INFO Generating embedding vector from input query
# 2025-07-22 16:16:45,442 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-22 16:16:45,443 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:45,451 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:45,452 INFO Tool selection complete!
# 2025-07-22 16:16:45,453 INFO 🚀 Starting tool execution process...
# 2025-07-22 16:16:45,454 INFO Searching by query: {"query":"React コンポーネント 作成方法"}
# [(11, 'React ナレッジ\n3\nUseContext\nグローバル変数みたいな使い方で、子コンポーネントに引数として渡していくのが\n大変なときに活用する\n型定義（Event編）\ntype Props = {\nonClick: (event: React.MouseEvent<HTMLInputElement>) => void\nonChange: (event: React.ChangeEvent<HTMLInputElement>) => void\nonkeypress: (event: React.KeyboardEvent<HTMLInputElement>) => void', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (5, 'https://qiita.com/gota5010/items/0caf9cf519bed85ea1fc\nnpm create vite@latest\ncd プロジェクト名\nnpm install\nnpm run dev\nReactプロジェクトのバージョン確認コマンド\nReact ナレッジ\n1\nnpm list react\nレンダリングとは\n再描画すること。ブラウザで画面リロードするわけではないけれど、必要なUIの部\n分だけを"もう一度作って表示し直す\n再レンダリングされるとき\nステートが変わる時\n開発モードの時は勝手に２回レンダリングされる', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (13, 'onSubmit: (event: React.FormEvent<HTMLFormElement>) => void\nonClickDiv: (event: React.MouseEvent<HTMLDivElement, MouseEvent>) => \nvoid\n}\nStrictModeについて\nReact ナレッジ\n4\n💡\ncreateRoot(document.getElementById("root")!).render(\n  <StrictMode>\n    {/* <App /> */}', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'})][(5, 'https://qiita.com/gota5010/items/0caf9cf519bed85ea1fc\nnpm create vite@latest\ncd プロジェクト名\nnpm install\nnpm run dev\nReactプロジェクトのバージョン確認コマンド\nReact ナレッジ\n1\nnpm list react\nレンダリングとは\n再描画すること。ブラウザで画面リロードするわけではないけれど、必要なUIの部\n分だけを"もう一度作って表示し直す\n再レンダリングされるとき\nステートが変わる時\n開発モードの時は勝手に２回レンダリングされる', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (4, 'React ナレッジ\nオーナー\n福田拓哉\nタグ\n手順 / プロセス\nプロジェクトの開始の仕方\n前提：Node.jsがインストールされていること\nhttps://nodejs.org/ja/download\nプロジェクトの開始\n下記はReact×Typescript\nnpx create-react-app {プロジェクト名} --template typescript\n最近はこっちになったらしい\nhttps://qiita.com/gota5010/items/0caf9cf519bed85ea1fc\nnpm create vite@latest\ncd プロジェクト名\nnpm install', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (15, '</StrictMode>\n);\n開発の時はStrictModeがついているので2回レンダリングされるのは普通。\n通常npm run buildすると自動的に削除してくれる\nReactのif文的なところ\nあんまりif文は使わず下記の書き方が多い\n💡{ 真偽値 && JSXの記述}\n💡{ 真偽値 ? true時の表示 : false時の表示}\nReactのfor文的なところ\n下記はよく見る使い方\n💡配列変数.map(value ⇒ 新しい項目)\nReact ナレッジ\n5\nReact ナレッジ\n6', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'})]
# 2025-07-22 16:16:45,597 INFO Finished searching QA by query
#
# 2025-07-22 16:16:45,597 INFO Finished searching QA by query
# 2025-07-22 16:16:45,598 INFO Tool execution complete!
# 2025-07-22 16:16:45,598 INFO Tool execution complete!
# 2025-07-22 16:16:45,600 INFO 🚀 Starting subtask answer creation process...
# 2025-07-22 16:16:45,601 INFO 🚀 Starting subtask answer creation process...
# 2025-07-22 16:16:45,601 INFO Sending request to OpenAI...
# 2025-07-22 16:16:45,602 INFO Sending request to OpenAI...
# 2025-07-22 16:16:46,061 INFO Generating embedding vector from input query
# 2025-07-22 16:16:46,131 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [(5, 'https://qiita.com/gota5010/items/0caf9cf519bed85ea1fc\nnpm create vite@latest\ncd プロジェクト名\nnpm install\nnpm run dev\nReactプロジェクトのバージョン確認コマンド\nReact ナレッジ\n1\nnpm list react\nレンダリングとは\n再描画すること。ブラウザで画面リロードするわけではないけれど、必要なUIの部\n分だけを"もう一度作って表示し直す\n再レンダリングされるとき\nステートが変わる時\n開発モードの時は勝手に２回レンダリングされる', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (4, 'React ナレッジ\nオーナー\n福田拓哉\nタグ\n手順 / プロセス\nプロジェクトの開始の仕方\n前提：Node.jsがインストールされていること\nhttps://nodejs.org/ja/download\nプロジェクトの開始\n下記はReact×Typescript\nnpx create-react-app {プロジェクト名} --template typescript\n最近はこっちになったらしい\nhttps://qiita.com/gota5010/items/0caf9cf519bed85ea1fc\nnpm create vite@latest\ncd プロジェクト名\nnpm install', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (15, '</StrictMode>\n);\n開発の時はStrictModeがついているので2回レンダリングされるのは普通。\n通常npm run buildすると自動的に削除してくれる\nReactのif文的なところ\nあんまりif文は使わず下記の書き方が多い\n💡{ 真偽値 && JSXの記述}\n💡{ 真偽値 ? true時の表示 : false時の表示}\nReactのfor文的なところ\n下記はよく見る使い方\n💡配列変数.map(value ⇒ 新しい項目)\nReact ナレッジ\n5\nReact ナレッジ\n6', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'})]
# 2025-07-22 16:16:46,146 INFO Finished searching QA by query
# 2025-07-22 16:16:46,147 INFO Tool execution complete!
# 2025-07-22 16:16:46,148 INFO 🚀 Starting subtask answer creation process...
# 2025-07-22 16:16:46,149 INFO Sending request to OpenAI...
# 2025-07-22 16:16:46,189 INFO Generating embedding vector from input query
# 2025-07-22 16:16:46,475 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [(15, '</StrictMode>\n);\n開発の時はStrictModeがついているので2回レンダリングされるのは普通。\n通常npm run buildすると自動的に削除してくれる\nReactのif文的なところ\nあんまりif文は使わず下記の書き方が多い\n💡{ 真偽値 && JSXの記述}\n💡{ 真偽値 ? true時の表示 : false時の表示}\nReactのfor文的なところ\n下記はよく見る使い方\n💡配列変数.map(value ⇒ 新しい項目)\nReact ナレッジ\n5\nReact ナレッジ\n6', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (5, 'https://qiita.com/gota5010/items/0caf9cf519bed85ea1fc\nnpm create vite@latest\ncd プロジェクト名\nnpm install\nnpm run dev\nReactプロジェクトのバージョン確認コマンド\nReact ナレッジ\n1\nnpm list react\nレンダリングとは\n再描画すること。ブラウザで画面リロードするわけではないけれど、必要なUIの部\n分だけを"もう一度作って表示し直す\n再レンダリングされるとき\nステートが変わる時\n開発モードの時は勝手に２回レンダリングされる', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (6, '分だけを"もう一度作って表示し直す\n再レンダリングされるとき\nステートが変わる時\n開発モードの時は勝手に２回レンダリングされる\nコンポーネントでpropsを受け取っていて、propsの値が変わった時\n親のコンポーネントが再レンダリングされた時\nUseState（よく使う）\nReactでは状態管理はすべてusestateを使って行う。\nUseEffect\n「再レンダリング後に何か処理をしたいとき」に使います。\nUseState使用時のレンダリングの際に、レンダリングループを止めたりできる\n◎初回だけAPIを呼び出す例', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'})]
# 2025-07-22 16:16:46,513 INFO Finished searching QA by query
# 2025-07-22 16:16:46,514 INFO Tool execution complete!
# 2025-07-22 16:16:46,515 INFO 🚀 Starting subtask answer creation process...
# 2025-07-22 16:16:46,515 INFO Sending request to OpenAI...
# 2025-07-22 16:16:46,653 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [(5, 'https://qiita.com/gota5010/items/0caf9cf519bed85ea1fc\nnpm create vite@latest\ncd プロジェクト名\nnpm install\nnpm run dev\nReactプロジェクトのバージョン確認コマンド\nReact ナレッジ\n1\nnpm list react\nレンダリングとは\n再描画すること。ブラウザで画面リロードするわけではないけれど、必要なUIの部\n分だけを"もう一度作って表示し直す\n再レンダリングされるとき\nステートが変わる時\n開発モードの時は勝手に２回レンダリングされる', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (11, 'React ナレッジ\n3\nUseContext\nグローバル変数みたいな使い方で、子コンポーネントに引数として渡していくのが\n大変なときに活用する\n型定義（Event編）\ntype Props = {\nonClick: (event: React.MouseEvent<HTMLInputElement>) => void\nonChange: (event: React.ChangeEvent<HTMLInputElement>) => void\nonkeypress: (event: React.KeyboardEvent<HTMLInputElement>) => void', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (15, '</StrictMode>\n);\n開発の時はStrictModeがついているので2回レンダリングされるのは普通。\n通常npm run buildすると自動的に削除してくれる\nReactのif文的なところ\nあんまりif文は使わず下記の書き方が多い\n💡{ 真偽値 && JSXの記述}\n💡{ 真偽値 ? true時の表示 : false時の表示}\nReactのfor文的なところ\n下記はよく見る使い方\n💡配列変数.map(value ⇒ 新しい項目)\nReact ナレッジ\n5\nReact ナレッジ\n6', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'})]
# 2025-07-22 16:16:46,667 INFO Finished searching QA by query
# 2025-07-22 16:16:46,668 INFO Tool execution complete!
# 2025-07-22 16:16:46,668 INFO 🚀 Starting subtask answer creation process...
# 2025-07-22 16:16:46,669 INFO Sending request to OpenAI...
# 2025-07-22 16:16:50,785 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:50,793 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:50,798 INFO Subtask answer creation complete!
# 2025-07-22 16:16:50,800 INFO 🚀 Starting reflection process...
# 2025-07-22 16:16:50,802 INFO Sending request to OpenAI...
# 2025-07-22 16:16:50,864 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:50,872 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:50,873 INFO Subtask answer creation complete!
# 2025-07-22 16:16:50,874 INFO 🚀 Starting reflection process...
# 2025-07-22 16:16:50,874 INFO Sending request to OpenAI...
# 2025-07-22 16:16:51,538 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:51,550 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:51,551 INFO Subtask answer creation complete!
# 2025-07-22 16:16:51,552 INFO 🚀 Starting reflection process...
# 2025-07-22 16:16:51,555 INFO Sending request to OpenAI...
# 2025-07-22 16:16:51,816 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:51,827 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:51,831 INFO Subtask answer creation complete!
# 2025-07-22 16:16:51,834 INFO 🚀 Starting reflection process...
# 2025-07-22 16:16:51,835 INFO Sending request to OpenAI...
# 2025-07-22 16:16:52,934 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:52,943 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:52,946 INFO Subtask answer creation complete!
# 2025-07-22 16:16:52,949 INFO 🚀 Starting reflection process...
# 2025-07-22 16:16:52,950 INFO Sending request to OpenAI...
# 2025-07-22 16:16:53,421 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:53,450 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:53,451 INFO Reflection complete!
# 2025-07-22 16:16:53,927 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:53,943 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:53,945 INFO Reflection complete!
# 2025-07-22 16:16:54,113 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:54,126 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:54,129 INFO Reflection complete!
# 2025-07-22 16:16:54,296 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:54,306 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:54,308 INFO Reflection complete!
# 2025-07-22 16:16:54,313 INFO 🚀 Starting tool selection process...
# 2025-07-22 16:16:54,324 INFO Sending request to OpenAI...
# 2025-07-22 16:16:54,940 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:54,949 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:54,950 INFO Reflection complete!
# 2025-07-22 16:16:55,982 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:16:55,990 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:16:55,994 INFO Tool selection complete!
# 2025-07-22 16:16:55,999 INFO 🚀 Starting tool execution process...
# 2025-07-22 16:16:56,001 INFO Searching by query: {"query":"React 状態管理 useReducer コンテキストAPI Redux"}
# 2025-07-22 16:16:56,711 INFO Generating embedding vector from input query
# 2025-07-22 16:16:57,130 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [(6, '分だけを"もう一度作って表示し直す\n再レンダリングされるとき\nステートが変わる時\n開発モードの時は勝手に２回レンダリングされる\nコンポーネントでpropsを受け取っていて、propsの値が変わった時\n親のコンポーネントが再レンダリングされた時\nUseState（よく使う）\nReactでは状態管理はすべてusestateを使って行う。\nUseEffect\n「再レンダリング後に何か処理をしたいとき」に使います。\nUseState使用時のレンダリングの際に、レンダリングループを止めたりできる\n◎初回だけAPIを呼び出す例', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (15, '</StrictMode>\n);\n開発の時はStrictModeがついているので2回レンダリングされるのは普通。\n通常npm run buildすると自動的に削除してくれる\nReactのif文的なところ\nあんまりif文は使わず下記の書き方が多い\n💡{ 真偽値 && JSXの記述}\n💡{ 真偽値 ? true時の表示 : false時の表示}\nReactのfor文的なところ\n下記はよく見る使い方\n💡配列変数.map(value ⇒ 新しい項目)\nReact ナレッジ\n5\nReact ナレッジ\n6', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'}), (11, 'React ナレッジ\n3\nUseContext\nグローバル変数みたいな使い方で、子コンポーネントに引数として渡していくのが\n大変なときに活用する\n型定義（Event編）\ntype Props = {\nonClick: (event: React.MouseEvent<HTMLInputElement>) => void\nonChange: (event: React.ChangeEvent<HTMLInputElement>) => void\nonkeypress: (event: React.KeyboardEvent<HTMLInputElement>) => void', {'source': 'PDF', 'file_name': '4615daec-bd30-4bce-a5ff-9fdac962a732_React_ナレッジ.pdf'})]
# 2025-07-22 16:16:57,181 INFO Finished searching QA by query
# 2025-07-22 16:16:57,182 INFO Tool execution complete!
# 2025-07-22 16:16:57,184 INFO 🚀 Starting subtask answer creation process...
# 2025-07-22 16:16:57,184 INFO Sending request to OpenAI...
# 2025-07-22 16:17:08,767 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:17:08,780 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:17:08,783 INFO Subtask answer creation complete!
# 2025-07-22 16:17:08,785 INFO 🚀 Starting reflection process...
# 2025-07-22 16:17:08,785 INFO Sending request to OpenAI...
# 2025-07-22 16:17:10,643 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:17:10,658 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:17:10,659 INFO Reflection complete!
# 2025-07-22 16:17:10,661 INFO 🚀 Starting final answer creation process...
# 2025-07-22 16:17:10,661 INFO Sending request to OpenAI...
# 2025-07-22 16:17:16,347 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-22 16:17:16,348 INFO ✅ Successfully received response from OpenAI.
# 2025-07-22 16:17:16,349 INFO Final answer creation complete!

# %%
# 回答
print(result.answer)
# Out:
# お世話になっております。
#
# Reactの利用についてご質問ありがとうございます。以下に、Reactの初期セットアップと主な使い方についての情報をまとめました。
#
# 1. **Reactの初期セットアップについて**
#
#    Reactを始めるためには、以下のソフトウェアとツールが必要です。
#
#    - **Node.js**: Reactプロジェクトを開始するために必要です。公式サイト（https://nodejs.org/ja/download）からダウンロードしてインストールしてください。
#    - **npm**: Node.jsをインストールすると一緒にインストールされます。Reactプロジェクトの依存関係を管理するために使用します。
#    - **npx**: `npx create-react-app`コマンドを使用して、Reactアプリケーションのテンプレートを迅速に作成します。
#
#    初期セットアップ手順は以下の通りです：
#
#    1. Node.jsをインストールします。
#    2. `npx create-react-app {プロジェクト名} --template typescript`コマンドでプロジェクトを作成します。
#    3. `cd {プロジェクト名}`でプロジェクトディレクトリに移動します。
#    4. `npm install`で依存関係をインストールします。
#    5. `npm run dev`で開発サーバーを起動します。
#
# 2. **Reactの主な使い方について**
#
#    - **コンポーネントの作成**: Reactでは、コンポーネントはJavaScriptの関数またはクラスとして定義されます。関数コンポーネントは`return`文でJSXを返し、クラスコンポーネントは`render`メソッドでJSXを返します。コンポーネントは再利用可能なUI部品として機能します。
#
#    - **状態管理**: 状態管理には`useState`や`useReducer`フック、コンテキストAPI、Reduxなどが使用されます。`useState`はシンプルな状態管理に、`useReducer`は複雑なロジックを持つ状態管理に適しています。コンテキストAPIはデータをコンポーネントツリー全体で共有するのに便利です。
#
#    - **イベントハンドリング**: Reactでは、イベントハンドリングにおいて型定義を行うことが一般的です。例えば、クリックイベントには`React.MouseEvent`を使用します。イベントハンドラは通常、コンポーネントのプロパティとして渡され、イベントが発生したときに呼び出されます。
#
# これらの情報がReactの利用を始める際の参考になれば幸いです。何か不明点があれば、引き続きご質問ください。
